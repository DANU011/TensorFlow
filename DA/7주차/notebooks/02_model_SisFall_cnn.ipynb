# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pickle

# 데이터셋 준비
train_df = pd.read_csv('../data/SisFall_train.csv')  # 훈련 파일
test_df = pd.read_csv('../data/SisFall_test.csv')  # 테스트 파일

X_train = []  # 훈련 입력 데이터
y_train = []  # 훈련 출력 데이터

X_test = []  # 테스트 입력 데이터
y_test = []  # 테스트 출력 데이터

# 4개의 레코드씩 묶어서 처리
for i in range(0, len(train_df) - 39, 40):
    # gx, gy, gz 값 가져오기
    gx_values = train_df.loc[i:i+39, 'gx'].values
    gy_values = train_df.loc[i:i+39, 'gy'].values
    gz_values = train_df.loc[i:i+39, 'gz'].values

    # 레이블 값 가져오기
    labels = train_df.loc[i:i+39, 'label'].values

    # 서로 다른 레이블이 포함된 경우 해당 시퀀스는 분석에서 제외
    if len(set(labels)) == 1:
        # 시퀀스로 변환하여 입력 데이터에 추가
        X_train.append(np.transpose([gx_values, gy_values, gz_values]))

        # 레이블 값 중복 제거하여 출력 데이터에 추가
        y_train.append(labels[0])

for i in range(0, len(test_df) - 39, 40):
    # gx, gy, gz 값 가져오기
    gx_values = test_df.loc[i:i+39, 'gx'].values
    gy_values = test_df.loc[i:i+39, 'gy'].values
    gz_values = test_df.loc[i:i+39, 'gz'].values

    # 레이블 값 가져오기
    labels = test_df.loc[i:i+39, 'label'].values

    # 서로 다른 레이블이 포함된 경우 해당 시퀀스는 분석에서 제외
    if len(set(labels)) == 1:
        # 시퀀스로 변환하여 입력 데이터에 추가
        X_test.append(np.transpose([gx_values, gy_values, gz_values]))

        # 레이블 값 중복 제거하여 출력 데이터에 추가
        y_test.append(labels[0])

# 입력 데이터와 출력 데이터를 넘파이 배열로 변환
X_train = np.array(X_train)
y_train = np.array(y_train)

X_test = np.array(X_test)
y_test = np.array(y_test)

# 출력 데이터를 One-Hot 인코딩
label_encoder = LabelEncoder()
integer_encoded_train = label_encoder.fit_transform(y_train)
integer_encoded_train = integer_encoded_train.reshape(len(integer_encoded_train), 1)
onehot_encoder_train = OneHotEncoder(sparse_output=False)
y_train = onehot_encoder_train.fit_transform(integer_encoded_train)

integer_encoded_test = label_encoder.transform(y_test)
integer_encoded_test = integer_encoded_test.reshape(len(integer_encoded_test), 1)
onehot_encoder_test = OneHotEncoder(sparse_output=False)
y_test = onehot_encoder_test.fit_transform(integer_encoded_test)

# 모델 정의
model = keras.models.Sequential()
model.add(keras.layers.Conv1D(64, 3, activation='relu', input_shape=(40, 3)))  # 40개의 시퀀스, 각 시퀀스에 3개의 피처
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(5, activation='softmax'))  # 분류할 클래스 수에 맞게 조정

# 모델 컴파일 및 학습
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# 최상의 적합 모델의 가중치를 피클 파일로 저장
best_model_weights = history.model.get_weights()
pickle.dump(best_model_weights, open('../model/best_model_weights_cnn.pkl', 'wb'))

# 레이블 인코더의 클래스 정보를 저장
np.save('../model/label_encoder_classes_cnn.npy', label_encoder.classes_)

# 모델 저장
model.save('../model/loaded_model_cnn.h5')

# 피클 파일에서 가중치 로드
loaded_model_weights = pickle.load(open('../model/best_model_weights_cnn.pkl', 'rb'))

# 모델에 로드된 가중치 설정
model.set_weights(loaded_model_weights)

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 저장
model.save('../model/loaded_model_cnn.h5')
# Out:
# Epoch 1/100
# 208/208 [==============================] - 1s 4ms/step - loss: 1.3945 - accuracy: 0.6183 - val_loss: 0.8845 - val_accuracy: 0.6639
# Epoch 2/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5993 - accuracy: 0.7842 - val_loss: 0.8114 - val_accuracy: 0.7128
# Epoch 3/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.4668 - accuracy: 0.8274 - val_loss: 0.7327 - val_accuracy: 0.7386
# Epoch 4/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3916 - accuracy: 0.8519 - val_loss: 0.8534 - val_accuracy: 0.7310
# Epoch 5/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3672 - accuracy: 0.8640 - val_loss: 0.6973 - val_accuracy: 0.7603
# Epoch 6/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3221 - accuracy: 0.8721 - val_loss: 0.7352 - val_accuracy: 0.7764
# Epoch 7/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2653 - accuracy: 0.8935 - val_loss: 0.7544 - val_accuracy: 0.7855
# Epoch 8/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2153 - accuracy: 0.9132 - val_loss: 1.0705 - val_accuracy: 0.7540
# Epoch 9/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2431 - accuracy: 0.9129 - val_loss: 1.3063 - val_accuracy: 0.6946
# Epoch 10/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2949 - accuracy: 0.8909 - val_loss: 0.8276 - val_accuracy: 0.7792
# Epoch 11/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2212 - accuracy: 0.9132 - val_loss: 1.0169 - val_accuracy: 0.7694
# Epoch 12/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2030 - accuracy: 0.9207 - val_loss: 0.9875 - val_accuracy: 0.7708
# Epoch 13/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1602 - accuracy: 0.9338 - val_loss: 1.0948 - val_accuracy: 0.7722
# Epoch 14/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1467 - accuracy: 0.9398 - val_loss: 1.0741 - val_accuracy: 0.7757
# Epoch 15/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1497 - accuracy: 0.9424 - val_loss: 1.2173 - val_accuracy: 0.7659
# Epoch 16/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1631 - accuracy: 0.9367 - val_loss: 1.1152 - val_accuracy: 0.7680
# Epoch 17/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1582 - accuracy: 0.9367 - val_loss: 1.2608 - val_accuracy: 0.7827
# Epoch 18/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1406 - accuracy: 0.9428 - val_loss: 1.2001 - val_accuracy: 0.7778
# Epoch 19/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1625 - accuracy: 0.9368 - val_loss: 1.2759 - val_accuracy: 0.7743
# Epoch 20/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1927 - accuracy: 0.9261 - val_loss: 1.1834 - val_accuracy: 0.7883
# Epoch 21/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1265 - accuracy: 0.9517 - val_loss: 1.6291 - val_accuracy: 0.7722
# Epoch 22/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2993 - accuracy: 0.9213 - val_loss: 1.3742 - val_accuracy: 0.7785
# Epoch 23/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1623 - accuracy: 0.9401 - val_loss: 1.3070 - val_accuracy: 0.7652
# Epoch 24/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1140 - accuracy: 0.9543 - val_loss: 1.2146 - val_accuracy: 0.7932
# Epoch 25/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0951 - accuracy: 0.9612 - val_loss: 1.3266 - val_accuracy: 0.7792
# Epoch 26/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0862 - accuracy: 0.9657 - val_loss: 1.2511 - val_accuracy: 0.7925
# Epoch 27/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0886 - accuracy: 0.9661 - val_loss: 1.3605 - val_accuracy: 0.7778
# Epoch 28/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1262 - accuracy: 0.9553 - val_loss: 1.4482 - val_accuracy: 0.7827
# Epoch 29/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0779 - accuracy: 0.9684 - val_loss: 1.4574 - val_accuracy: 0.8008
# Epoch 30/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0671 - accuracy: 0.9734 - val_loss: 1.6144 - val_accuracy: 0.7862
# Epoch 31/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0632 - accuracy: 0.9755 - val_loss: 1.5885 - val_accuracy: 0.8008
# Epoch 32/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0587 - accuracy: 0.9770 - val_loss: 1.9343 - val_accuracy: 0.7771
# Epoch 33/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1458 - accuracy: 0.9552 - val_loss: 1.6958 - val_accuracy: 0.7645
# Epoch 34/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2331 - accuracy: 0.9380 - val_loss: 2.1733 - val_accuracy: 0.7589
# Epoch 35/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1880 - accuracy: 0.9439 - val_loss: 1.4532 - val_accuracy: 0.7869
# Epoch 36/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1051 - accuracy: 0.9648 - val_loss: 1.7203 - val_accuracy: 0.7792
# Epoch 37/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0761 - accuracy: 0.9698 - val_loss: 1.6625 - val_accuracy: 0.7911
# Epoch 38/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0613 - accuracy: 0.9774 - val_loss: 1.5878 - val_accuracy: 0.7966
# Epoch 39/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0482 - accuracy: 0.9828 - val_loss: 1.7268 - val_accuracy: 0.7869
# Epoch 40/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0534 - accuracy: 0.9800 - val_loss: 1.5618 - val_accuracy: 0.7980
# Epoch 41/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0715 - accuracy: 0.9756 - val_loss: 1.7723 - val_accuracy: 0.7876
# Epoch 42/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1761 - accuracy: 0.9506 - val_loss: 1.9313 - val_accuracy: 0.7876
# Epoch 43/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0949 - accuracy: 0.9723 - val_loss: 1.7396 - val_accuracy: 0.7904
# Epoch 44/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1483 - accuracy: 0.9654 - val_loss: 1.7633 - val_accuracy: 0.7862
# Epoch 45/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0616 - accuracy: 0.9779 - val_loss: 1.8491 - val_accuracy: 0.7904
# Epoch 46/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0419 - accuracy: 0.9848 - val_loss: 1.9340 - val_accuracy: 0.7869
# Epoch 47/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0357 - accuracy: 0.9893 - val_loss: 1.8177 - val_accuracy: 0.7952
# Epoch 48/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0332 - accuracy: 0.9872 - val_loss: 1.8867 - val_accuracy: 0.7959
# Epoch 49/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0313 - accuracy: 0.9901 - val_loss: 1.9480 - val_accuracy: 0.7932
# Epoch 50/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 1.9877 - val_accuracy: 0.7980
# Epoch 51/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0288 - accuracy: 0.9899 - val_loss: 2.1487 - val_accuracy: 0.7848
# Epoch 52/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 2.0975 - val_accuracy: 0.7925
# Epoch 53/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 2.1725 - val_accuracy: 0.7827
# Epoch 54/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 2.2577 - val_accuracy: 0.7827
# Epoch 55/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0209 - accuracy: 0.9950 - val_loss: 2.2840 - val_accuracy: 0.7883
# Epoch 56/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 2.3450 - val_accuracy: 0.7582
# Epoch 57/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3299 - accuracy: 0.9347 - val_loss: 1.4846 - val_accuracy: 0.7911
# Epoch 58/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1369 - accuracy: 0.9664 - val_loss: 1.8310 - val_accuracy: 0.7757
# Epoch 59/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0823 - accuracy: 0.9785 - val_loss: 1.5758 - val_accuracy: 0.7869
# Epoch 60/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0417 - accuracy: 0.9883 - val_loss: 1.7547 - val_accuracy: 0.7792
# Epoch 61/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0253 - accuracy: 0.9944 - val_loss: 1.8413 - val_accuracy: 0.7939
# Epoch 62/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0237 - accuracy: 0.9944 - val_loss: 1.8885 - val_accuracy: 0.7848
# Epoch 63/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0177 - accuracy: 0.9956 - val_loss: 1.8912 - val_accuracy: 0.7897
# Epoch 64/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 1.9292 - val_accuracy: 0.7932
# Epoch 65/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0170 - accuracy: 0.9956 - val_loss: 2.0685 - val_accuracy: 0.7841
# Epoch 66/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0266 - accuracy: 0.9925 - val_loss: 2.2384 - val_accuracy: 0.7904
# Epoch 67/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1106 - accuracy: 0.9714 - val_loss: 2.3197 - val_accuracy: 0.7652
# Epoch 68/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1252 - accuracy: 0.9735 - val_loss: 1.8594 - val_accuracy: 0.7911
# Epoch 69/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0837 - accuracy: 0.9807 - val_loss: 2.5961 - val_accuracy: 0.7498
# Epoch 70/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0553 - accuracy: 0.9871 - val_loss: 2.7138 - val_accuracy: 0.7652
# Epoch 71/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0156 - accuracy: 0.9967 - val_loss: 2.4663 - val_accuracy: 0.7792
# Epoch 72/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0151 - accuracy: 0.9964 - val_loss: 2.4673 - val_accuracy: 0.7820
# Epoch 73/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0129 - accuracy: 0.9977 - val_loss: 2.6832 - val_accuracy: 0.7715
# Epoch 74/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.9971 - val_loss: 2.5772 - val_accuracy: 0.7799
# Epoch 75/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 2.5789 - val_accuracy: 0.7785
# Epoch 76/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 2.6165 - val_accuracy: 0.7757
# Epoch 77/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0875 - accuracy: 0.9841 - val_loss: 2.6310 - val_accuracy: 0.7715
# Epoch 78/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1061 - accuracy: 0.9779 - val_loss: 3.4268 - val_accuracy: 0.7470
# Epoch 79/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1227 - accuracy: 0.9732 - val_loss: 2.5369 - val_accuracy: 0.7736
# Epoch 80/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 0.9919 - val_loss: 2.6279 - val_accuracy: 0.7673
# Epoch 81/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0477 - accuracy: 0.9914 - val_loss: 2.5702 - val_accuracy: 0.7855
# Epoch 82/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0237 - accuracy: 0.9952 - val_loss: 2.9318 - val_accuracy: 0.7764
# Epoch 83/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0152 - accuracy: 0.9959 - val_loss: 2.7841 - val_accuracy: 0.7827
# Epoch 84/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 2.7928 - val_accuracy: 0.7848
# Epoch 85/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 2.8685 - val_accuracy: 0.7827
# Epoch 86/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 2.9162 - val_accuracy: 0.7827
# Epoch 87/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 2.8888 - val_accuracy: 0.7827
# Epoch 88/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 2.9403 - val_accuracy: 0.7806
# Epoch 89/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 3.0373 - val_accuracy: 0.7778
# Epoch 90/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 3.0631 - val_accuracy: 0.7813
# Epoch 91/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 3.1227 - val_accuracy: 0.7771
# Epoch 92/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 3.2104 - val_accuracy: 0.7764
# Epoch 93/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 3.2639 - val_accuracy: 0.7750
# Epoch 94/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 2.8011 - val_accuracy: 0.7932
# Epoch 95/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1387 - accuracy: 0.9770 - val_loss: 2.4634 - val_accuracy: 0.7848
# Epoch 96/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2142 - accuracy: 0.9640 - val_loss: 2.0883 - val_accuracy: 0.7876
# Epoch 97/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0468 - accuracy: 0.9886 - val_loss: 2.4770 - val_accuracy: 0.7813
# Epoch 98/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0386 - accuracy: 0.9935 - val_loss: 2.8469 - val_accuracy: 0.7827
# Epoch 99/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 2.7099 - val_accuracy: 0.7834
# Epoch 100/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 2.7011 - val_accuracy: 0.7848

# %%
import matplotlib.pyplot as plt

# Get the training history
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim([0, 1])
plt.show()

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0, 1])
plt.show()
